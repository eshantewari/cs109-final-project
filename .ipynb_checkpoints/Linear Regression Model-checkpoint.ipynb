# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import statsmodels.api as sm
from sklearn.linear_model import Lasso, Ridge

# pandas tricks for better display
pd.options.display.max_columns = 50  
pd.options.display.max_rows = 500     
pd.options.display.max_colwidth = 100
pd.options.display.precision = 3

# %matplotlib inline

# %% [markdown]
# # Prepare data

# %%
data = pd.read_csv("performance_year_financial_and_quality_results_puf_2020_01_01.csv")

# %%
#all of these are directly tied to the response variable and as such we do not want them as predictors
vars_to_exclude = ["EarnSaveLoss", "GenSaveLoss","BnchmkMinExp"] 
data_mod = data.drop(vars_to_exclude, axis=1)

#Drop non-relevant categorial columns
cat_cols_to_encode = ["Rev_Exp_Cat", "Risk_Model", "Agree_Type"]
cols = data_mod.columns
num_cols = data_mod._get_numeric_data().columns
vars_to_exclude = list(set(cols) - set(num_cols) - set(cat_cols_to_encode))
data_mod = data_mod.drop(vars_to_exclude, axis=1)

#one-hot encode relevant categorial columns
data_mod = pd.get_dummies(data_mod, columns=cat_cols_to_encode)

nans = ['DisAdj', 'PosRegAdj', 'Adv_Pay_Amt','Adv_Pay_Recoup']
data_mod = data_mod.drop(nans, axis=1)

X = data_mod.drop(['Sav_rate'], axis=1)
y = data_mod['Sav_rate']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.8, random_state=34)

# %%
X_train.shape
# Out:
# (410, 131)

# %% [markdown]
# # Baseline Linear Regression

# %%
X_train_sm = sm.add_constant(X_train, prepend=True, has_constant='add')
model = sm.OLS(y_train, X_train_sm)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Sav_rate   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                     123.3
# Date:                Mon, 06 Dec 2021   Prob (F-statistic):          4.33e-197
# Time:                        15:32:51   Log-Likelihood:                 1482.4
# No. Observations:                 410   AIC:                            -2721.
# Df Residuals:                     288   BIC:                            -2231.
# Df Model:                         121
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                          -0.0024      0.013     -0.187      0.852      -0.028       0.023
# Agreement_Period_Num        -3.168e-05      0.001     -0.027      0.979      -0.002       0.002
# Current_Track_1                -0.0081      0.006     -1.285      0.200      -0.021       0.004
# Current_Track_2                -0.0071      0.007     -0.982      0.327      -0.021       0.007
# Current_Track_3                -0.0146      0.024     -0.611      0.542      -0.061       0.032
# Current_Track_1_Plus            0.0155      0.011      1.417      0.157      -0.006       0.037
# Current_BASIC_A                 0.0094      0.008      1.193      0.234      -0.006       0.025
# Current_BASIC_B                 0.0060      0.008      0.777      0.438      -0.009       0.021
# Current_BASIC_C                 0.0139      0.012      1.195      0.233      -0.009       0.037
# Current_BASIC_D                -0.0086      0.016     -0.551      0.582      -0.039       0.022
# Current_BASIC_E                 0.0135      0.011      1.194      0.234      -0.009       0.036
# Current_ENHANCED               -0.0222      0.024     -0.923      0.357      -0.069       0.025
# Adv_Pay                        -0.0003      0.003     -0.107      0.915      -0.007       0.006
# AIM                             0.0044      0.003      1.670      0.096      -0.001       0.010
# SNF_Waiver                     -0.0002      0.002     -0.110      0.912      -0.003       0.003
# N_AB                           -0.0015      0.005     -0.300      0.765      -0.011       0.008
# MinSavPerc                     -0.0418      0.071     -0.593      0.553      -0.181       0.097
# DisAffQual                     -0.0024      0.013     -0.187      0.852      -0.028       0.023
# Met_QPS                        -0.0024      0.013     -0.187      0.852      -0.028       0.023
# QualScore                      -0.0002      0.001     -0.191      0.849      -0.002       0.002
# RecvdMean                       0.0005      0.001      0.365      0.715      -0.002       0.003
# RegTrndUpdt                    -0.0016      0.003     -0.473      0.637      -0.008       0.005
# UpdatedBnchmk                8.619e-05   2.24e-06     38.412      0.000    8.18e-05    9.06e-05
# HistBnchmk                  -1.004e-06    2.5e-06     -0.401      0.689   -5.93e-06    3.92e-06
# ABtotBnchmk                  2.772e-10   9.26e-11      2.994      0.003    9.49e-11    4.59e-10
# ABtotExp                    -2.974e-10   9.03e-11     -3.295      0.001   -4.75e-10    -1.2e-10
# QualPerfShare                  -0.0127      0.015     -0.863      0.389      -0.041       0.016
# FinalShareRate                  0.1442      0.151      0.952      0.342      -0.154       0.442
# RevLossLimit                   -0.0025      0.006     -0.433      0.666      -0.014       0.009
# Per_Capita_Exp_ALL_ESRD_BY1 -1.822e-07    7.2e-08     -2.532      0.012   -3.24e-07   -4.05e-08
# Per_Capita_Exp_ALL_DIS_BY1   9.895e-07   8.13e-07      1.216      0.225   -6.11e-07    2.59e-06
# Per_Capita_Exp_ALL_AGDU_BY1  4.503e-07   4.09e-07      1.101      0.272   -3.55e-07    1.26e-06
# Per_Capita_Exp_ALL_AGND_BY1 -3.222e-06   1.63e-06     -1.977      0.049   -6.43e-06   -1.37e-08
# Per_Capita_Exp_ALL_ESRD_BY2  1.404e-07   7.12e-08      1.971      0.050    2.15e-10    2.81e-07
# Per_Capita_Exp_ALL_DIS_BY2  -7.872e-07   8.51e-07     -0.925      0.356   -2.46e-06    8.88e-07
# Per_Capita_Exp_ALL_AGDU_BY2 -1.879e-07   4.23e-07     -0.444      0.657   -1.02e-06    6.45e-07
# Per_Capita_Exp_ALL_AGND_BY2 -1.448e-06   1.76e-06     -0.822      0.411   -4.91e-06    2.02e-06
# Per_Capita_Exp_ALL_ESRD_BY3 -5.186e-08    6.1e-08     -0.850      0.396   -1.72e-07    6.83e-08
# Per_Capita_Exp_ALL_DIS_BY3    2.43e-06   7.76e-07      3.130      0.002    9.02e-07    3.96e-06
# Per_Capita_Exp_ALL_AGDU_BY3  5.756e-07   3.94e-07      1.460      0.145      -2e-07    1.35e-06
# Per_Capita_Exp_ALL_AGND_BY3 -5.597e-06   1.67e-06     -3.348      0.001   -8.89e-06   -2.31e-06
# Per_Capita_Exp_ALL_ESRD_PY   4.248e-08    6.3e-08      0.674      0.501   -8.15e-08    1.66e-07
# Per_Capita_Exp_ALL_DIS_PY    3.252e-07   7.26e-07      0.448      0.654    -1.1e-06    1.75e-06
# Per_Capita_Exp_ALL_AGDU_PY   -8.57e-07   3.18e-07     -2.696      0.007   -1.48e-06   -2.31e-07
# Per_Capita_Exp_ALL_AGND_PY   1.068e-05    2.3e-06      4.633      0.000    6.14e-06    1.52e-05
# Per_Capita_Exp_TOTAL_PY     -9.055e-05   6.67e-06    -13.574      0.000      -0.000   -7.74e-05
# CMS_HCC_RiskScore_ESRD_BY1      0.0299      0.013      2.225      0.027       0.003       0.056
# CMS_HCC_RiskScore_DIS_BY1       0.0043      0.015      0.288      0.773      -0.025       0.034
# CMS_HCC_RiskScore_AGDU_BY1     -0.0010      0.013     -0.076      0.939      -0.026       0.024
# CMS_HCC_RiskScore_AGND_BY1      0.0315      0.026      1.191      0.234      -0.021       0.083
# CMS_HCC_RiskScore_ESRD_BY2      0.0220      0.014      1.558      0.120      -0.006       0.050
# CMS_HCC_RiskScore_DIS_BY2      -0.0168      0.017     -0.964      0.336      -0.051       0.018
# CMS_HCC_RiskScore_AGDU_BY2      0.0134      0.013      1.034      0.302      -0.012       0.039
# CMS_HCC_RiskScore_AGND_BY2      0.0283      0.033      0.860      0.390      -0.036       0.093
# CMS_HCC_RiskScore_ESRD_BY3     -0.0297      0.013     -2.364      0.019      -0.054      -0.005
# CMS_HCC_RiskScore_DIS_BY3      -0.0067      0.016     -0.412      0.680      -0.038       0.025
# CMS_HCC_RiskScore_AGDU_BY3     -0.0246      0.015     -1.604      0.110      -0.055       0.006
# CMS_HCC_RiskScore_AGND_BY3     -0.0165      0.029     -0.568      0.570      -0.074       0.041
# CMS_HCC_RiskScore_ESRD_PY       0.0055      0.013      0.437      0.662      -0.019       0.030
# CMS_HCC_RiskScore_DIS_PY        0.0117      0.012      0.952      0.342      -0.013       0.036
# CMS_HCC_RiskScore_AGDU_PY       0.0041      0.011      0.368      0.713      -0.018       0.026
# CMS_HCC_RiskScore_AGND_PY      -0.0158      0.017     -0.932      0.352      -0.049       0.018
# N_AB_Year_ESRD_BY3          -3.067e-05   2.59e-05     -1.186      0.237   -8.16e-05    2.02e-05
# N_AB_Year_DIS_BY3            7.372e-06   2.27e-06      3.253      0.001    2.91e-06    1.18e-05
# N_AB_Year_AGED_Dual_BY3     -2.055e-05   2.89e-06     -7.108      0.000   -2.62e-05   -1.49e-05
# N_AB_Year_AGED_NonDual_BY3   5.863e-07   2.75e-07      2.132      0.034     4.5e-08    1.13e-06
# N_AB_Year_PY                   -0.0014      0.001     -1.937      0.054      -0.003     2.3e-05
# N_AB_Year_ESRD_PY               0.0014      0.001      1.985      0.048    1.19e-05       0.003
# N_AB_Year_DIS_PY                0.0014      0.001      1.927      0.055   -3.03e-05       0.003
# N_AB_Year_AGED_Dual_PY          0.0014      0.001      1.969      0.050    4.14e-07       0.003
# N_AB_Year_AGED_NonDual_PY       0.0014      0.001      1.942      0.053   -1.89e-05       0.003
# N_Ben_Age_0_64                 -0.0004      0.001     -0.297      0.766      -0.003       0.002
# N_Ben_Age_65_74                -0.0004      0.001     -0.300      0.764      -0.003       0.002
# N_Ben_Age_75_84                -0.0004      0.001     -0.301      0.763      -0.003       0.002
# N_Ben_Age_85plus               -0.0004      0.001     -0.300      0.765      -0.003       0.002
# N_Ben_Female                    0.0021      0.007      0.299      0.765      -0.012       0.016
# N_Ben_Male                      0.0021      0.007      0.299      0.765      -0.012       0.016
# N_Ben_Race_White               -0.0002      0.001     -0.301      0.764      -0.002       0.001
# N_Ben_Race_Black               -0.0002      0.001     -0.299      0.765      -0.002       0.001
# N_Ben_Race_Asian               -0.0002      0.001     -0.299      0.765      -0.002       0.001
# N_Ben_Race_Hisp                -0.0002      0.001     -0.298      0.766      -0.002       0.001
# N_Ben_Race_Native              -0.0002      0.001     -0.298      0.766      -0.002       0.001
# N_Ben_Race_Other               -0.0002      0.001     -0.303      0.762      -0.002       0.001
# CapAnn_INP_All               5.271e-05   3.55e-05      1.484      0.139   -1.72e-05       0.000
# CapAnn_INP_S_trm            -5.685e-05   3.43e-05     -1.660      0.098      -0.000    1.06e-05
# CapAnn_INP_L_trm            -7.059e-05   3.01e-05     -2.345      0.020      -0.000   -1.13e-05
# CapAnn_INP_Rehab             -5.69e-05   3.59e-05     -1.586      0.114      -0.000    1.37e-05
# CapAnn_INP_Psych            -7.533e-05   3.92e-05     -1.921      0.056      -0.000    1.84e-06
# CapAnn_HSP                   -6.83e-06   7.06e-06     -0.967      0.334   -2.07e-05    7.08e-06
# CapAnn_SNF                   1.538e-05    6.6e-06      2.331      0.020     2.4e-06    2.84e-05
# CapAnn_OPD                   -5.53e-07   6.14e-06     -0.090      0.928   -1.26e-05    1.15e-05
# CapAnn_PB                   -3.668e-06   6.22e-06     -0.589      0.556   -1.59e-05    8.58e-06
# CapAnn_AmbPay                3.609e-05   1.35e-05      2.672      0.008     9.5e-06    6.27e-05
# CapAnn_HHA                  -4.795e-06   6.64e-06     -0.723      0.471   -1.79e-05    8.27e-06
# CapAnn_DME                  -2.213e-06   1.19e-05     -0.186      0.853   -2.56e-05    2.12e-05
# ADM                            -0.0008      0.001     -1.430      0.154      -0.002       0.000
# ADM_S_Trm                       0.0008      0.001      1.345      0.180      -0.000       0.002
# ADM_L_Trm                       0.0017      0.001      2.148      0.033       0.000       0.003
# ADM_Rehab                       0.0010      0.001      1.624      0.105      -0.000       0.002
# ADM_Psych                       0.0010      0.001      1.590      0.113      -0.000       0.002
# chf_adm                      9.736e-05      0.000      0.446      0.656      -0.000       0.001
# copd_adm                     6.332e-07      0.000      0.002      0.999      -0.001       0.001
# prov_Rate_1000              -3.999e-05   2.16e-05     -1.854      0.065   -8.25e-05    2.47e-06
# P_EDV_Vis                   -1.072e-05   1.04e-05     -1.030      0.304   -3.12e-05    9.78e-06
# P_EDV_Vis_HOSP               4.196e-05   3.75e-05      1.118      0.265   -3.19e-05       0.000
# P_CT_VIS                     6.741e-07   7.34e-06      0.092      0.927   -1.38e-05    1.51e-05
# P_MRI_VIS                    1.192e-05   2.09e-05      0.571      0.568   -2.91e-05     5.3e-05
# P_EM_Total                      0.0009      0.001      1.258      0.210      -0.001       0.002
# P_EM_PCP_Vis                   -0.0009      0.001     -1.256      0.210      -0.002       0.001
# P_EM_SP_Vis                    -0.0009      0.001     -1.257      0.210      -0.002       0.001
# P_Nurse_Vis                    -0.0009      0.001     -1.254      0.211      -0.002       0.001
# P_FQHC_RHC_Vis                 -0.0009      0.001     -1.258      0.210      -0.002       0.001
# P_SNF_ADM                    2.005e-05   6.75e-05      0.297      0.767      -0.000       0.000
# N_CAH                       -4.458e-05      0.000     -0.209      0.835      -0.000       0.000
# N_FQHC                       4.183e-05    3.6e-05      1.161      0.247   -2.91e-05       0.000
# N_RHC                       -1.258e-05      0.000     -0.091      0.927      -0.000       0.000
# N_ETA                          -0.0013      0.002     -0.767      0.444      -0.005       0.002
# N_Hosp                          0.0004      0.000      1.280      0.201      -0.000       0.001
# N_Fac_Other                  -3.26e-05      0.000     -0.316      0.752      -0.000       0.000
# N_PCP                       -6.366e-06   5.79e-06     -1.100      0.272   -1.78e-05    5.02e-06
# N_Spec                       1.947e-06   2.36e-06      0.826      0.409   -2.69e-06    6.58e-06
# N_NP                        -4.245e-06   7.14e-06     -0.594      0.553   -1.83e-05    9.82e-06
# N_PA                         4.407e-06   5.54e-06      0.795      0.427    -6.5e-06    1.53e-05
# N_CNS                          -0.0001      0.000     -0.962      0.337      -0.000       0.000
# ACO43                          -0.0028      0.003     -0.947      0.345      -0.009       0.003
# Rev_Exp_Cat_High Revenue       -0.0032      0.006     -0.487      0.626      -0.016       0.010
# Rev_Exp_Cat_Low Revenue         0.0007      0.007      0.112      0.911      -0.012       0.014
# Risk_Model_One-Sided            0.0073      0.011      0.683      0.495      -0.014       0.028
# Risk_Model_Two-Sided           -0.0097      0.011     -0.921      0.358      -0.030       0.011
# Agree_Type_Initial             -0.0030      0.005     -0.616      0.539      -0.012       0.007
# Agree_Type_Re-Entering          0.0007      0.005      0.159      0.874      -0.008       0.010
# Agree_Type_Renewal             -0.0002      0.004     -0.041      0.968      -0.009       0.009
# ==============================================================================
# Omnibus:                       12.654   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               21.887
# Skew:                          -0.169   Prob(JB):                     1.77e-05
# Kurtosis:                       4.080   Cond. No.                     1.38e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.16e-13. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
#Print Coefficients with Significant P value

pvals = results.pvalues
coefs = results.params


results_df = pd.DataFrame({"coef": coefs, "P-value":pvals})
sig_coefs = results_df[results_df["P-value"] <= .05]
sig_coefs.sort_values(by = ['P-value'], inplace=True, axis=0)
sig_coefs.to_csv("Results/significant_coefs.csv")
sig_coefs
# Out:
# <ipython-input-27-77fa2a90c1c0>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_coefs.sort_values(by = ['P-value'], inplace=True, axis=0)
#                                   coef     P-value
# UpdatedBnchmk                8.619e-05  2.423e-115
# Per_Capita_Exp_TOTAL_PY     -9.055e-05   8.821e-33
# N_AB_Year_AGED_Dual_BY3     -2.055e-05   9.273e-12
# Per_Capita_Exp_ALL_AGND_PY   1.068e-05   5.456e-06
# Per_Capita_Exp_ALL_AGND_BY3 -5.597e-06   9.221e-04
# ABtotExp                    -2.974e-10   1.109e-03
# N_AB_Year_DIS_BY3            7.372e-06   1.277e-03
# Per_Capita_Exp_ALL_DIS_BY3   2.430e-06   1.929e-03
# ABtotBnchmk                  2.772e-10   2.996e-03
# Per_Capita_Exp_ALL_AGDU_PY  -8.570e-07   7.422e-03
# CapAnn_AmbPay                3.609e-05   7.979e-03
# Per_Capita_Exp_ALL_ESRD_BY1 -1.822e-07   1.189e-02
# CMS_HCC_RiskScore_ESRD_BY3  -2.969e-02   1.874e-02
# CapAnn_INP_L_trm            -7.059e-05   1.969e-02
# CapAnn_SNF                   1.538e-05   2.042e-02
# CMS_HCC_RiskScore_ESRD_BY1   2.989e-02   2.687e-02
# ADM_L_Trm                    1.694e-03   3.257e-02
# N_AB_Year_AGED_NonDual_BY3   5.863e-07   3.386e-02
# N_AB_Year_ESRD_PY            1.446e-03   4.814e-02
# Per_Capita_Exp_ALL_AGND_BY1 -3.222e-06   4.904e-02
# Per_Capita_Exp_ALL_ESRD_BY2  1.404e-07   4.965e-02
# N_AB_Year_AGED_Dual_PY       1.435e-03   4.993e-02

# %%
#Linear Regression with Cross Validation

lr = LinearRegression()

results = cross_validate(lr, X_train, y_train, cv=10, scoring = 'neg_mean_squared_error', return_train_score=True)
train_mse_lr = np.mean(-1*results['train_score'])
val_mse_lr = np.mean(-1*results['test_score'])
val_mse_stds_lr = np.std(-1*results['test_score'])
    
print(f"Mean training set MSE: {train_mse_lr:.7f}. Mean validation set MSE: {val_mse_lr:.7f} ")


#Overall Fitted Model
lr.fit(X_train, y_train)
train_mse_lr_full = mean_squared_error(lr.predict(X_train), y_train)
r2_train_lr_full = r2_score(lr.predict(X_train), y_train)

test_mse_lr_full = mean_squared_error(lr.predict(X_test), y_test)
r2_test_lr_full = r2_score(lr.predict(X_test), y_test)

print(f"Overall training set MSE: {train_mse_lr_full:.7f}. Overall test set MSE: {test_mse_lr_full:.7f} ")
print(f"Overall training set R2: {r2_train_lr_full:.3f}. Overall test set R2: {r2_test_lr_full:.3f} ")
# Out:
# Mean training set MSE: 0.0000389. Mean validation set MSE: 0.0003108
# Overall training set MSE: 0.0000424. Overall test set MSE: 0.0001696
# Overall training set R2: 0.981. Overall test set R2: 0.907

# %% [markdown]
# # Residual Plot

# %%
yhat = lr.predict(X_train)

figure, axs = plt.subplots(1,2, figsize=(15,5))
axs = axs.ravel()

resid = y_train - yhat
axs[0].scatter(yhat, resid)
axs[0].set_xlabel("Predicted Value")
axs[0].set_ylabel("Residual")
axs[0].set_title("Residuals vs Predicted Values")

axs[1].hist(resid)
axs[1].set_xlabel("Residual")
axs[1].set_ylabel("Frequency")
axs[1].set_title("Distribution of Residuals")
plt.savefig('Project_images/regression_residuals.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # Checking for Multicolinearity

# %%
corr=data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# /Users/eshan/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style.py:1126: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# /Users/eshan/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style.py:1127: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
# #T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row0_col0,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row1_col1,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row2_col2,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row3_col3,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row4_col4,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row5_col5,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row6_col6,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row7_col7,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row8_col8,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row9_col9,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row10_col10,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row11_col11,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row12_col12,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row13_col13,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row14_col14,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row14_col73,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row14_col79,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row14_col82,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row14_col83,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row15_col15,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row16_col16,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row17_col17,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row18_col18,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row20_col20,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row23_col23,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row24_col24,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row25_col25,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row26_col26,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row27_col27,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row28_col28,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row29_col29,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row29_col30,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row30_col29,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row30_col30,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row31_col31,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row32_col32,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row33_col33,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row33_col34,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row34_col33,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row34_col34,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row35_col35,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row36_col36,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row37_col37,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row38_col38,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row39_col39,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row40_col40,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row41_col41,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row42_col42,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row43_col43,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row44_col44,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row45_col45,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row46_col46,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row47_col47,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row48_col48,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row49_col49,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row50_col50,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row51_col51,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row52_col52,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row53_col53,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row54_col54,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row55_col55,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row56_col56,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row57_col57,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row58_col58,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row59_col59,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row60_col60,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row61_col61,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row62_col62,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row63_col63,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row64_col64,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row65_col65,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row66_col66,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row67_col67,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row68_col68,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row69_col69,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row70_col70,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row71_col71,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row72_col72,#T_aa55a0e8_550b_11ec_be38_367ddab8c0b5row ...

# %% [markdown]
# There are a number of variable pairs exhibiting high degrees of correlation, so I would like to try running a regression on top of a PCA-transformed dataset instead

# %% [markdown]
# # Scale Data

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Perform PCA
pca = PCA().fit(X_train_scaled)
X_train_pca = pca.transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# %%
# Plot explained variance for pca components
fig, ax = plt.subplots(nrows=2, figsize=(15,10))
ax1, ax2 = ax.ravel()

ratio = pca.explained_variance_ratio_
num_components = 20
ax1.bar(range(num_components), ratio[ :num_components], color='purple', alpha=0.8)
ax1.set_title('Explained Variance Ratio PCA', fontsize=20)
ax1.set_xticks(range(num_components))
ax1.set_xticklabels(['PC {}'.format(i+1) for i in range(num_components)])
ax1.set_ylabel('Explained Variance Ratio')

ratio = pca.explained_variance_ratio_
ax2.plot(np.cumsum(ratio[ :num_components]), 'o-')

ax2.set_title('Cumulative Sum of Explained Variance Ratio PCA', fontsize=20)

ax2.set_ylim(0,1.1)
ax2.set_xticks(range(num_components))
ax2.set_xticklabels(['PC {}'.format(i+1) for i in range(num_components)])
ax2.set_ylabel('Cumulative Sum of Explained Variance Ratio');

plt.savefig('Project_images/PCA_explained_variance.pdf', bbox_inches="tight")

# %%
#Observe Classification Boundary with first two components
figure, axs = plt.subplots(1,2, figsize=(5.5,2))
axs = axs.ravel()
cm = plt.cm.get_cmap('RdYlBu')
sc1 = axs[0].scatter(X_train_pca[:,0], X_train_pca[:,1], c = y_train, s=1.5)
axs[0].set_xlim([-5, 5])
axs[0].set_ylim([-5, 5])
axs[0].set_xlabel("PCA 1", fontsize=5)
axs[0].set_ylabel("PCA 2", fontsize=5)
axs[0].tick_params(axis='x', labelsize=5)
axs[0].tick_params(axis='y', labelsize=5)
axs[0].set_title("Savings Rate vs First Two Principal Components", fontsize=6)
cbar = fig.colorbar(sc1, ax = axs[0])
cbar.ax.tick_params(labelsize=5)

sc2 = axs[1].scatter(X_train_pca[:,0], X_train_pca[:,1], c = [1 if y_i >= 0 else 0 for y_i in y_train], s=1.5)
axs[1].set_xlim([-5, 5])
axs[1].set_ylim([-5, 5])
axs[1].set_xlabel("PCA 1", fontsize=5)
axs[1].set_ylabel("PCA 2", fontsize=5)
axs[1].tick_params(axis='x', labelsize=5)
axs[1].tick_params(axis='y', labelsize=5)
axs[1].set_title("Savings Rate vs First Two Principal Components. \n1 = generated savings, 0 = did not generate savings", fontsize=6)
cbar = fig.colorbar(sc2, ax = axs[1])
cbar.ax.tick_params(labelsize=5)
plt.savefig('Project_images/PCA_two_components.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# No clear classification boundary in 2D

# %%
#Linear Regression with Cross Validation

lr_pca = LinearRegression()

n_components = 20

results = cross_validate(lr_pca, X_train_pca[:,:n_components], y_train, cv=10, scoring = 'neg_mean_squared_error', return_train_score=True)
train_mse_lr_pca = np.mean(-1*results['train_score'])
val_mse_lr_pca = np.mean(-1*results['test_score'])
val_mse_stds_lr_pca = np.std(-1*results['test_score'])
    
print(f"Mean training set MSE: {train_mse_lr_pca:.7f}. Mean validation set MSE: {val_mse_lr_pca:.7f} ")


#Overall Fitted Model
lr_pca.fit(X_train_pca[:,:n_components], y_train)
train_mse_lr_pca_full = mean_squared_error(lr_pca.predict(X_train_pca[:,:n_components]), y_train)
r2_train_lr_pca_full = r2_score(lr_pca.predict(X_train_pca[:,:n_components]), y_train)

test_mse_lr_pca_full = mean_squared_error(lr_pca.predict(X_test_pca[:,:n_components]), y_test)
r2_test_lr_pca_full = r2_score(lr_pca.predict(X_test_pca[:,:n_components]), y_test)

print(f"Overall training set MSE: {train_mse_lr_pca_full:.7f}. Overall test set MSE: {test_mse_lr_pca_full:.7f} ")
print(f"Overall training set R2: {r2_train_lr_pca_full:.3f}. Overall test set R2: {r2_test_lr_pca_full:.3f} ")
# Out:
# Mean training set MSE: 0.0011766. Mean validation set MSE: 0.0015765
# Overall training set MSE: 0.0011898. Overall test set MSE: 0.0010358
# Overall training set R2: -0.136. Overall test set R2: -0.335

# %% [markdown]
# # Lasso Linear Regression

# %%
# %%capture --no-stdout --no-display

# your code here
train_MSEs = []
val_MSEs = []
val_MSEs_stds = []

alphas = [1e-3, 1e-2, 1e-1, 1e0, 1e1]

for alpha in alphas:    
    # Initialize a Lasso Linear Regression object
    lasso = Lasso(alpha = alpha, max_iter=10000)
    
    results = cross_validate(lasso, X_train_scaled, y_train, cv=10, scoring = 'neg_mean_squared_error', return_train_score=True)
    train_MSEs.append(np.mean(-1*results['train_score']))
    val_MSEs.append(np.mean(-1*results['test_score']))
    val_MSEs_stds.append(np.std(-1*results['test_score']))

plt.plot(alphas, train_MSEs, label="Train MSE")
plt.errorbar(alphas, val_MSEs, label="Validation MSE", yerr=val_MSEs_stds)
plt.xlabel("alpha")
plt.ylabel("MSE")
plt.legend()
plt.title("Alpha Paramater for Lasso Model vs Train and Validation MSEs")
plt.savefig('Project_images/lasso_tuning.pdf', bbox_inches="tight")
plt.show()

best_alpha_lasso = alphas[val_MSEs.index(min(val_MSEs))]
train_mse_lasso = train_MSEs[val_MSEs.index(min(val_MSEs))]
val_mse_lasso = min(val_MSEs)


print(f"Alpha of Best Model: {best_alpha_lasso}. Mean training set MSE: {train_mse_lasso:.7f}. Mean validation set MSE: {val_mse_lasso:.7f} ")


#Overall Fitted Model
lasso = Lasso(alpha = best_alpha_lasso, max_iter=10000)
lasso.fit(X_train, y_train)
train_mse_lasso_full = mean_squared_error(lasso.predict(X_train), y_train)
r2_train_lasso_full = r2_score(lasso.predict(X_train), y_train)

test_mse_lasso_full = mean_squared_error(lasso.predict(X_test), y_test)
r2_test_lasso_full = r2_score(lasso.predict(X_test), y_test)

print(f"Overall training set MSE: {train_mse_lasso_full:.7f}. Overall test set MSE: {test_mse_lasso_full:.7f} ")
print(f"Overall training set R2: {r2_train_lasso_full:.3f}. Overall test set R2: {r2_test_lasso_full:.3f} ")
# Out:
# Alpha of Best Model: 0.001. Mean training set MSE: 0.0002043. Mean validation set MSE: 0.0003447
# Overall training set MSE: 0.0000545. Overall test set MSE: 0.0001798
# Overall training set R2: 0.975. Overall test set R2: 0.897

# %%
#Print significant coefficients


results_df = pd.DataFrame({"Variable": X_train.columns, "Coef":lasso.coef_})
sig_coefs = results_df[np.abs(results_df["Coef"]) > 1e-5]

#here we can roughly sort by the absolute value of coefficient value due to standardization
sig_coefs["Abs Coef"] = [np.abs(x) for x in sig_coefs["Coef"]]
sig_coefs.sort_values(by = ['Abs Coef'], inplace=True, ascending=False, axis=0)
sig_coefs.drop(['Abs Coef'], axis=1, inplace=True)
sig_coefs.to_csv("Results/lasso_coefs.csv")

sig_coefs
# Out:
# <ipython-input-39-cebe5e6801dd>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_coefs["Abs Coef"] = [np.abs(x) for x in sig_coefs["Coef"]]
# <ipython-input-39-cebe5e6801dd>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_coefs.sort_values(by = ['Abs Coef'], inplace=True, ascending=False, axis=0)
# /Users/eshan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                     Variable       Coef
# 114                    N_RHC  1.325e-04
# 44   Per_Capita_Exp_TOTAL_PY -8.839e-05
# 21             UpdatedBnchmk  8.428e-05
# 113                   N_FQHC  5.911e-05
# 111                P_SNF_ADM  5.381e-05
# 66         N_AB_Year_ESRD_PY  5.264e-05
# 61        N_AB_Year_ESRD_BY3 -5.242e-05
# 103           P_EDV_Vis_HOSP  3.604e-05
# 95                 ADM_S_Trm -3.407e-05
# 91             CapAnn_AmbPay  2.782e-05
# 86          CapAnn_INP_Psych -2.488e-05
# 63   N_AB_Year_AGED_Dual_BY3 -2.485e-05
# 68    N_AB_Year_AGED_Dual_PY  2.269e-05
# 83          CapAnn_INP_S_trm -1.864e-05
# 101           prov_Rate_1000 -1.782e-05
# 105                P_MRI_VIS  1.493e-05
# 82            CapAnn_INP_All  1.199e-05
# 67          N_AB_Year_DIS_PY -1.115e-05
# 121                     N_PA  1.103e-05
# 62         N_AB_Year_DIS_BY3  1.050e-05

# %% [markdown]
# # Ridge Linear Regression

# %%
# %%capture --no-stdout --no-display

# your code here
train_MSEs = []
val_MSEs = []
val_MSEs_stds = []

alphas = [1e-3, 1e-2, 1e-1, 1e0, 1e1]

for alpha in alphas:    
    # Initialize a Ridge Linear Regression object
    ridge = Ridge(alpha = alpha, max_iter=10000)
    
    results = cross_validate(ridge, X_train_scaled, y_train, cv=10, scoring = 'neg_mean_squared_error', return_train_score=True)
    train_MSEs.append(np.mean(-1*results['train_score']))
    val_MSEs.append(np.mean(-1*results['test_score']))
    val_MSEs_stds.append(np.std(-1*results['test_score']))

plt.plot(alphas, train_MSEs, label="Train MSE")
plt.errorbar(alphas, val_MSEs, label="Validation MSE", yerr=val_MSEs_stds)
plt.xlabel("alpha")
plt.ylabel("MSE")
plt.legend()
plt.title("Alpha Paramater for Ridge Model vs Train and Validation MSEs")
plt.savefig('Project_images/ridge_tuning.pdf', bbox_inches="tight")
plt.show()

best_alpha_ridge = alphas[val_MSEs.index(min(val_MSEs))]
train_mse_ridge = train_MSEs[val_MSEs.index(min(val_MSEs))]
val_mse_ridge = min(val_MSEs)


print(f"Alpha of Best Model: {best_alpha_ridge}. Mean training set MSE: {train_mse_ridge:.7f}. Mean validation set MSE: {val_mse_ridge:.7f} ")

#Overall Fitted Model
ridge = Ridge(alpha = best_alpha_ridge, max_iter=10000)
ridge.fit(X_train, y_train)
train_mse_ridge_full = mean_squared_error(ridge.predict(X_train), y_train)
r2_train_ridge_full = r2_score(ridge.predict(X_train), y_train)

test_mse_ridge_full = mean_squared_error(ridge.predict(X_test), y_test)
r2_test_ridge_full = r2_score(ridge.predict(X_test), y_test)

print(f"Overall training set MSE: {train_mse_ridge_full:.7f}. Overall test set MSE: {test_mse_ridge_full:.7f} ")
print(f"Overall training set R2: {r2_train_ridge_full:.3f}. Overall test set R2: {r2_test_ridge_full:.3f} ")
# Out:
# Alpha of Best Model: 0.001. Mean training set MSE: 0.0000397. Mean validation set MSE: 0.0003124
# Overall training set MSE: 0.0000424. Overall test set MSE: 0.0001699
# Overall training set R2: 0.981. Overall test set R2: 0.907

# %%
#Print significant coefficients

results_df = pd.DataFrame({"Variable": X_train.columns, "Coef":ridge.coef_})
sig_coefs = results_df[np.abs(results_df["Coef"]) > 1e-2]

#here we can roughly sort by the absolute value of coefficient value due to standardization
sig_coefs["Abs Coef"] = [np.abs(x) for x in sig_coefs["Coef"]]
sig_coefs.sort_values(by = ['Abs Coef'], inplace=True, ascending=False, axis=0)
sig_coefs.drop(['Abs Coef'], axis=1, inplace=True)
sig_coefs.to_csv("Results/ridge_coefs.csv")

sig_coefs
# Out:
# <ipython-input-38-d992f1e76de0>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_coefs["Abs Coef"] = [np.abs(x) for x in sig_coefs["Coef"]]
# <ipython-input-38-d992f1e76de0>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sig_coefs.sort_values(by = ['Abs Coef'], inplace=True, ascending=False, axis=0)
# /Users/eshan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                       Variable   Coef
# 26              FinalShareRate  0.102
# 15                  MinSavPerc -0.039
# 48  CMS_HCC_RiskScore_AGND_BY1  0.031
# 45  CMS_HCC_RiskScore_ESRD_BY1  0.030
# 53  CMS_HCC_RiskScore_ESRD_BY3 -0.030
# 52  CMS_HCC_RiskScore_AGND_BY2  0.028
# 55  CMS_HCC_RiskScore_AGDU_BY3 -0.024
# 49  CMS_HCC_RiskScore_ESRD_BY2  0.022
# 50   CMS_HCC_RiskScore_DIS_BY2 -0.016
# 56  CMS_HCC_RiskScore_AGND_BY3 -0.016
# 10            Current_ENHANCED -0.016
# 60   CMS_HCC_RiskScore_AGND_PY -0.016
# 51  CMS_HCC_RiskScore_AGDU_BY2  0.013
# 4         Current_Track_1_Plus  0.013
# 58    CMS_HCC_RiskScore_DIS_PY  0.012
# 8              Current_BASIC_D -0.011
# 7              Current_BASIC_C  0.011
# 9              Current_BASIC_E  0.011

# %% [markdown]
# # Linear Model Summary

# %%
lm_df = pd.DataFrame({"Model":["Linear Regression", "PCA-Transformed Linear Regression", "Lasso Regression", "Ridge Regression"],
         "Mean Training MSE": [train_mse_lr, train_mse_lr_pca, train_mse_lasso, train_mse_ridge ],
         "Mean Validation MSE": [val_mse_lr, val_mse_lr_pca, val_mse_lasso, val_mse_ridge],
         "Training Set MSE":[train_mse_lr_full, train_mse_lr_pca_full, train_mse_lasso_full, train_mse_ridge_full],
         "Test Set MSE":[test_mse_lr_full, test_mse_lr_pca_full, test_mse_lasso_full, test_mse_ridge_full],   
         "Train Set R2":[r2_train_lr_full, r2_train_lr_pca_full, r2_train_lasso_full, r2_train_ridge_full], 
         "Test Set R2":[r2_test_lr_full, r2_test_lr_pca_full, r2_test_lasso_full, r2_test_ridge_full], 
        })
lm_df.set_index("Model", inplace=True)
lm_df.to_csv("Results/linear_model_summary.csv")
lm_df
# Out:
#                                    Mean Training MSE  Mean Validation MSE  \
# Model
# Linear Regression                          3.886e-05            3.108e-04
# PCA-Transformed Linear Regression          1.177e-03            1.576e-03
# Lasso Regression                           2.043e-04            3.447e-04
# Ridge Regression                           3.966e-05            3.124e-04
#
#                                    Training Set MSE  Test Set MSE  \
# Model
# Linear Regression                         4.236e-05     1.696e-04
# PCA-Transformed Linear Regression         1.190e-03     1.036e-03
# Lasso Regression                          5.449e-05     1.798e-04
# Ridge Regression                          4.238e-05     1.699e-04
#
#                                    Train Set R2  Test Set R2
# Model
# Linear Regression                         0.981        0.907
# PCA-Transformed Linear Regression        -0.136       -0.335
# Lasso Regression                          0.975        0.897
# Ridge Regression                          0.981        0.907

# %%
print("Significant Coefficients from Linear Regression (ranked by p-value)")

sig_coefs
# Out:
# Significant Coefficients from Linear Regression (ranked by p-value)
#                                   coef     P-value
# UpdatedBnchmk                8.619e-05  2.423e-115
# Per_Capita_Exp_TOTAL_PY     -9.055e-05   8.821e-33
# N_AB_Year_AGED_Dual_BY3     -2.055e-05   9.273e-12
# Per_Capita_Exp_ALL_AGND_PY   1.068e-05   5.456e-06
# Per_Capita_Exp_ALL_AGND_BY3 -5.597e-06   9.221e-04
# ABtotExp                    -2.974e-10   1.109e-03
# N_AB_Year_DIS_BY3            7.372e-06   1.277e-03
# Per_Capita_Exp_ALL_DIS_BY3   2.430e-06   1.929e-03
# ABtotBnchmk                  2.772e-10   2.996e-03
# Per_Capita_Exp_ALL_AGDU_PY  -8.570e-07   7.422e-03
# CapAnn_AmbPay                3.609e-05   7.979e-03
# Per_Capita_Exp_ALL_ESRD_BY1 -1.822e-07   1.189e-02
# CMS_HCC_RiskScore_ESRD_BY3  -2.969e-02   1.874e-02
# CapAnn_INP_L_trm            -7.059e-05   1.969e-02
# CapAnn_SNF                   1.538e-05   2.042e-02
# CMS_HCC_RiskScore_ESRD_BY1   2.989e-02   2.687e-02
# ADM_L_Trm                    1.694e-03   3.257e-02
# N_AB_Year_AGED_NonDual_BY3   5.863e-07   3.386e-02
# N_AB_Year_ESRD_PY            1.446e-03   4.814e-02
# Per_Capita_Exp_ALL_AGND_BY1 -3.222e-06   4.904e-02
# Per_Capita_Exp_ALL_ESRD_BY2  1.404e-07   4.965e-02
# N_AB_Year_AGED_Dual_PY       1.435e-03   4.993e-02

# %%
plt.scatter(data['UpdatedBnchmk'], data['Sav_rate'])

# %%
data['UpdatedBnchmk'].describe()
# Out:
# count      513.000
# mean     10960.173
# std       2335.281
# min       7832.000
# 25%       9807.000
# 50%      10546.000
# 75%      11552.000
# max      32669.000
# Name: UpdatedBnchmk, dtype: float64

# %%
data['Per_Capita_Exp_TOTAL_PY'].describe()
# Out:
# count      513.000
# mean     10536.456
# std       2398.338
# min       7476.000
# 25%       9343.000
# 50%      10133.000
# 75%      11138.000
# max      36652.000
# Name: Per_Capita_Exp_TOTAL_PY, dtype: float64
